# %%
1*2
# Out:
# 2

# %%
print("learning euron")
# Out:
# learning euron

# %%
a=1
b=2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
c=52.34

# %%
type(c)
# Out:
# float

# %%
d="aariz"

# %%
type(d)
# Out:
# str

# %%
id(c)
# Out:
# 1913432154096

# %%
id(d)
# Out:
# 1915551171312

# %%
g=True

type(g)
# Out:
# bool

# %%
h=False
type(h)
# Out:
# bool

# %%
True+True
# Out:
# 2

# %%
False+False
# Out:
# 0

# %%
True+False
# Out:
# 1

# %%
True*20
# Out:
# 20

# %%
True-False
# Out:
# 1

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
True/True
# Out:
# 1.0

# %%
q=3+6j

# %%
type(q)
# Out:
# complex

# %%
id(q)
# Out:
# 1913449971088

# %%
q.imag
# Out:
# 6.0

# %%
q.real
# Out:
# 3.0

# %%
h=None
type(h)
# Out:
# NoneType

# %%
None==0
# Out:
# False

# %%
None==False
# Out:
# False

# %%
id(h)
# Out:
# 140727299509008

# %%
MAX=1000

# %%
first_name="aariz"
last_name="Mobin"

# %%
print("first_name")
# Out:
# first_name

# %%
print(first_name)
# Out:
# aariz

# %%
print(last_name)
# Out:
# Mobin

# %%
print_first_name()-Function

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a="45"

a
# Out:
# '45'

# %%
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 45

# %%
float(a)
# Out:
# 45.0

# %%
b="aariz"

type(b)
# Out:
# str

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: 'aariz'

# %%
d=23.23
str(d)
# Out:
# '23.23'

# %%
n='True'

type(n)
# Out:
# str

# %%
bool(n)
# Out:
# True

# %%
a=34
b=13.45

a+b
# Out:
# 47.45

# %%
10+True
# Out:
# 11

# %%
10+False
# Out:
# 10

# %%
11-True
# Out:
# 10

# %%
0.1+0.2 #floating point precision issue
# Out:
# 0.30000000000000004

# %%
0.1+0.2==0.3
# Out:
# False

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.radians
# Out:
# <function math.radians(x, /)>

# %%
math.floor(math.pi)
# Out:
# 3

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.tau
# Out:
# 6.283185307179586

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.pow(4,5)
# Out:
# 1024.0

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
math.factorial(5)
# Out:
# 120

# %%
math.log (100)
# Out:
# 4.605170185988092

# %%
math.isclose(0.1+0.2,0.3)
# Out:
# True

# %%
math.cos(345)
# Out:
# 0.8390879278598296

# %%
import datetime
current_hour=datetime.datetime.now().hour
print(current_hour)
greeting="good morning" if current_hour <12 else "good afternoon" if current_hour <18 else "good evening" if current_hour <21 else "good night"
print(greeting)
# Out:
# 11
# good morning
