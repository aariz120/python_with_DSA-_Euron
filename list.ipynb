# %%
print("Now we will study list")
# Out:
# Now we will study list

# %% [markdown]
# # List

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
l=[3,4,5,6,7,8]

# %%
l
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
l1=[4,56,56,True,"eesha",45+8j]

# %%
l1[0]
# Out:
# 4

# %%
l1[-1]
# Out:
# (45+8j)

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j)]

# %%
l1[0:3]
# Out:
# [4, 56, 56]

# %%
l1[::-1]
# Out:
# [(45+8j), 'eesha', True, 56, 56, 4]

# %%
l1[::]
# Out:
# [4, 56, 56, True, 'eesha', (45+8j)]

# %%
l1[4][2]
# Out:
# 's'

# %%
list("eesha")
# Out:
# ['e', 'e', 's', 'h', 'a']

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j)]

# %%
l1.append(4)

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4]

# %%
l1.extend([45,78])

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4, 45, 78]

# %%
l1.insert(2,"new item")

# %%
l1
# Out:
# [4, 56, 'new item', 56, True, 'eesha', (45+8j), 4, 45, 78]

# %%
l1.insert(100,34)

# %%
l1
# Out:
# [4, 56, 'new item', 56, True, 'eesha', (45+8j), 4, 45, 78, 34]

# %%
l1.remove("new item")

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4, 45, 78, 34]

# %%
l1.pop()
# Out:
# 34

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4, 45, 78]

# %%
l1.index(4)
# Out:
# 0

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4, 45, 78]

# %%
l1.count(4)
# Out:
# 2

# %%
l1.reverse()

# %%
l1
# Out:
# [78, 45, 4, (45+8j), 'eesha', True, 56, 56, 4]

# %%
l1.reverse()

# %%
l1()
# Out:
# [4, 56, 56, True, 'eesha', (45+8j), 4, 45, 78]

# %%
l2=[3,4,5,6]

# %%
l3=l1=l2

# %%
l3
# Out:
# [3, 4, 5, 6]

# %%
l3.clear()

# %%
l2.clear()

# %%
l1
# Out:
# []

# %%
l1=[4,56,56,True,"eesha",45+8j]

# %%
l1
# Out:
# [4, 56, 56, True, 'eesha', (45+8j)]

# %%
l=[3,4,5,6]

# %%
l
# Out:
# [3, 4, 5, 6]

# %%
l1=l

# %%
l1
# Out:
# [3, 4, 5, 6]

# %%
l
# Out:
# [3, 4, 5, 6]

# %%
l2=l.copy()

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
l[0]
# Out:
# 3

# %%
l[0]="sudh"

# %%
l
# Out:
# ['sudh', 4, 5, 6]

# %%
l1
# Out:
# ['sudh', 4, 5, 6]

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
6 in l1
# Out:
# True

# %%
7 in l1
# Out:
# False

# %%
l1*4
# Out:
# ['sudh', 4, 5, 6, 'sudh', 4, 5, 6, 'sudh', 4, 5, 6, 'sudh', 4, 5, 6]

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
l1+l2
# Out:
# ['sudh', 4, 5, 6, 3, 4, 5, 6]

# %%
l3=["eesha","mobin"]

# %%
" ".join(l3)
# Out:
# 'eesha mobin'

# %%
e="eeshamobin"

# %%
e.split("m")
# Out:
# ['eesha', 'obin']

# %%
l=[5,6,7,[4,5,6,"mobin"],[5,6,7,8]]

# %%
l[4][2]
# Out:
# 7

# %%
for i in l:
     print(i)
# Out:
# 5
# 6
# 7
# [4, 5, 6, 'mobin']
# [5, 6, 7, 8]

# %%
for i in l:
    if type (i)==list:
        print(i)
# Out:
# [4, 5, 6, 'mobin']
# [5, 6, 7, 8]

# %%
len(l)
# Out:
# 5

# %%
l=[5,6,7,8,9,10]

# %%
max(l)
# Out:
# 10

# %%
min(l)
# Out:
# 5
