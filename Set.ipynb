# %%
print("we will study set")
# Out:
# we will study set

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s={4,5,6,7,8,9,4,5,6,6,8,9,7,5,4,3,"eesha","mobin","eesha"}

# %%
type(s)
# Out:
# set

# %%
s
# Out:
# {3, 4, 5, 6, 7, 8, 9, 'eesha', 'mobin'}

# %%
s1={45,56,78,89,7,5,True,"eesha","mobin"}

# %%
s1
# Out:
# {45, 5, 56, 7, 78, 89, True, 'eesha', 'mobin'}

# %%
s2={(4,5,6,7,True,"eesha")}

# %%
s2
# Out:
# {(4, 5, 6, 7, True, 'eesha')}

# %%
s3={[4,5,6,7,True,"eesha"]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s3={[4,5,6,7,True,"eesha"]}
#
# TypeError: unhashable type: 'list'

# %%
s4={5,6,77,{"eesha","data scientist","mobin","web developer"},(4,5,6)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s4={5,6,77,{"eesha","data scientist","mobin","web developer"},(4,5,6)}
#
# TypeError: unhashable type: 'set'

# %%
s5={2,3,4,5,6,7,8,87,2,3,5,8,9}

# %%
s5
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 87}

# %%
s6={23,"eesha",45,56,7,8,}

# %%
s6
# Out:
# {23, 45, 56, 7, 8, 'eesha'}

# %%
s6.add(4)

# %%
s6
# Out:
# {23, 4, 45, 56, 7, 8, 'eesha'}

# %%
s6.add("mobin")

# %%
s6
# Out:
# {23, 4, 45, 56, 7, 8, 'eesha', 'mobin'}

# %%
s6.update([12,3])

# %%
s6
# Out:
# {12, 23, 3, 4, 45, 56, 7, 8, 'eesha', 'mobin'}

# %%
s2.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s2.remove(5)
#
# KeyError: 5

# %%
s6.remove(4)

# %%
s6
# Out:
# {12, 23, 3, 45, 56, 7, 8, 'eesha', 'mobin'}

# %%
s6.discard(56)

# %%
s6.pop()
# Out:
# 3

# %%
s6
# Out:
# {12, 23, 45, 7, 8, 'eesha', 'mobin'}

# %%
s6
# Out:
# {12, 23, 45, 7, 8, 'eesha', 'mobin'}

# %%
s8=s6.copy()

# %%
s8
# Out:
# {12, 23, 45, 7, 8, 'eesha', 'mobin'}

# %%
len(s8)
# Out:
# 7

# %%
45 in s8
# Out:
# True

# %%
s1={2,3,4,5}
s2={4,5,6,7}

# %%
s1.union(s2)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.difference(s2)
# Out:
# {2, 3}

# %%
s2.difference(s1)
# Out:
# {6, 7}

# %%
a={1,2,}
b={1,2,3}

# %%
a.issubset(b)
# Out:
# True

# %%
b.issubset(a)
# Out:
# False

# %%
f=frozenset({1,2,3,4,5})

# %%
f
# Out:
# frozenset({1, 2, 3, 4, 5})
