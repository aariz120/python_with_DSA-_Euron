# %%
t=()

# %%
type(t)
# Out:
# tuple

# %%
t=(4,56,7,True,"Euron",6+4j)

# %%
t
# Out:
# (4, 56, 7, True, 'Euron', (6+4j))

# %%
t[0]
# Out:
# 4

# %%
t[0:3]
# Out:
# (4, 56, 7)

# %%
t[::-1]
# Out:
# ((6+4j), 'Euron', True, 7, 56, 4)

# %%
t[::]
# Out:
# (4, 56, 7, True, 'Euron', (6+4j))

# %%
t[0]="eesha"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t[0]="eesha"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=1
b=2
c=8

# %%
t=1,2,8

# %%
t
# Out:
# (1, 2, 8)

# %%
x,y,z=t

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 8

# %%
t
# Out:
# (1, 2, 8)

# %%
for i in t:
    print(i)
# Out:
# 1
# 2
# 8

# %%
t
# Out:
# (1, 2, 8)

# %%
t.count(1)
# Out:
# 1

# %%
t.index(8)
# Out:
# 2

# %%
list(t)
# Out:
# [1, 2, 8]

# %%
t
# Out:
# (1, 2, 8)

# %%
t=(4,5,6,[2,5,6],(7,8,9),True,"eesha")

# %%
t
# Out:
# (4, 5, 6, [2, 5, 6], (7, 8, 9), True, 'eesha')

# %%
t[3][2]
# Out:
# 6

# %%
t
# Out:
# (4, 5, 6, [2, 5, 6], (7, 8, 9), True, 'eesha')

# %%
4 in t
# Out:
# True

# %%
for i in t:
    print(i)
# Out:
# 4
# 5
# 6
# [2, 5, 6]
# (7, 8, 9)
# True
# eesha
