# %%
print(True)
# Out:
# True

# %%
True
# Out:
# True

# %%
True+True
# Out:
# 2

# %%
True*True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
False+False
# Out:
# 0

# %%
True+False
# Out:
# 1

# %%
5>1
# Out:
# True

# %%
5>8
# Out:
# False

# %%
5<3
# Out:
# False

# %%
4==4
# Out:
# True

# %%
9==10
# Out:
# False

# %%
(5==6)*5
# Out:
# 0

# %%
(4==4)*5
# Out:
# 5

# %%
(True+True)*10
# Out:
# 20

# %%
(False+False)*6
# Out:
# 0

# %%
5 >=3
# Out:
# True

# %%
3>=5
# Out:
# False

# %%
7<=3
# Out:
# False

# %%
8<=9
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
## operators= And ,or , Not

True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or Flase
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
5<3 or 5>4
# Out:
# True

# %%
5==5 and 6==9
# Out:
# False

# %%
5==5 or 6==9
# Out:
# True

# %%
#not > and >or

# %%
True or False and False
# Out:
# True

# %%
(True or False) and False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
not(True or False)
# Out:
# False

# %%
not(True and False)
# Out:
# True

# %%
3+2>5
# Out:
# False

# %%
10-5 ==5 and 2*2==4
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
bool(56)
# Out:
# True

# %%
bool(-89)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool("help")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
a=5
b=a

# %%
id(a)
# Out:
# 140726855451560

# %%
id(b)
# Out:
# 140726855451560

# %%
a is b
# Out:
# True

# %%
x=7
y=7
id(x)
# Out:
# 140726855451624

# %%
id(y)
# Out:
# 140726855451624

# %%
x is y
# Out:
# True

# %%
y is x
# Out:
# True

# %%
q=[1,2,3]
v=[1,2,3]
id(v)
# Out:
# 1744475447040

# %%
id(q)
# Out:
# 1744489177536

# %%
q is v
# Out:
# False

# %%
v is q
# Out:
# False

# %%
q is not v
# Out:
# True
